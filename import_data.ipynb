# %%
import pandas as pd
from sqlalchemy import create_engine

# Load your Excel file directly
file_path = r"C:\Users\dell\OneDrive - University of East Anglia\Data Analysis_Itonline\Reqruitment Support-ITOL\DA Project\sql-da-project\CWT-1.xlsx"
df = pd.read_excel(file_path, sheet_name=0)

# Connect to your local MySQL database
engine = create_engine('mysql+pymysql://root:a123@localhost/nhs_cancer_db')

# Push data to MySQL table instantly
df.to_sql('cancer_waiting_times', con=engine, if_exists='replace', index=False)

print(f"Successfully loaded {len(df)} rows into MySQL!")
# Out:
# Successfully loaded 61967 rows into MySQL!
